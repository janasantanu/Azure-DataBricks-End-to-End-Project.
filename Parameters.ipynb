# %%
import json

datasets = [
    {
        "file_name":"orders"
    },
    {
        "file_name":"products"
    },
    {
        "file_name":"customers"
    }
]

dbutils.jobs.taskValues.set(
    key = "output_datasets",
    value = json.dumps(datasets)
)
